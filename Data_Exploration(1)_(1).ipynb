# %% [markdown]
# <a href="https://colab.research.google.com/github/akechsmith/ICS-2207-SCIENTIFIC-COMPUTING/blob/main/Data_Exploration(1)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
import pandas as pd

# %%
data=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

# %%
data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data.tail(3)
# Out:
#        0    1    2    3               4
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
data.sample(10)
# Out:
#        0    1    2    3                4
# 105  7.6  3.0  6.6  2.1   Iris-virginica
# 66   5.6  3.0  4.5  1.5  Iris-versicolor
# 144  6.7  3.3  5.7  2.5   Iris-virginica
# 58   6.6  2.9  4.6  1.3  Iris-versicolor
# 125  7.2  3.2  6.0  1.8   Iris-virginica
# 4    5.0  3.6  1.4  0.2      Iris-setosa
# 50   7.0  3.2  4.7  1.4  Iris-versicolor
# 132  6.4  2.8  5.6  2.2   Iris-virginica
# 94   5.6  2.7  4.2  1.3  Iris-versicolor
# 135  7.7  3.0  6.1  2.3   Iris-virginica

# %%
data.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
data.columns=['sepal length','sepal width','petal length','petal width', 'class']

# %%
data
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Next we can explore the data - by computing some statical measures.

# %%
from pandas.api.types import is_numeric_dtype

# %%
for col in data.columns:
  if is_numeric_dtype(data[col]):
    print('%s:'%(col))
    print('\t Mean = %.2f'% data[col].mean())
    print('\t Standard Deviation=%.2f'%data[col].std())
    print('\t Minimum Value =%.2f'%data[col].min())
    print('\t Maximum Value =%.2f'%data[col].max())
# Out:
# sepal length:
# 	 Mean = 5.84
# 	 Standard Deviation=0.83
# 	 Minimum Value =4.30
# 	 Maximum Value =7.90
# sepal width:
# 	 Mean = 3.05
# 	 Standard Deviation=0.43
# 	 Minimum Value =2.00
# 	 Maximum Value =4.40
# petal length:
# 	 Mean = 3.76
# 	 Standard Deviation=1.76
# 	 Minimum Value =1.00
# 	 Maximum Value =6.90
# petal width:
# 	 Mean = 1.20
# 	 Standard Deviation=0.76
# 	 Minimum Value =0.10
# 	 Maximum Value =2.50

# %%
data['petal width'].value_counts()
# Out:
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: petal width, dtype: int64

# %%
data['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
data.describe(include='all')
# Out:
#         sepal length  sepal width  petal length  petal width        class
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN

# %% [markdown]
# multivariate data - with such data we can calculate the covariance and correlation

# %%
print('Covarience')
data.cov()
# Out:
# Covarience
# <ipython-input-27-2accbe2bc98b>:2: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.cov()
#               sepal length  sepal width  petal length  petal width
# sepal length      0.685694    -0.039268      1.273682     0.516904
# sepal width      -0.039268     0.188004     -0.321713    -0.117981
# petal length      1.273682    -0.321713      3.113179     1.296387
# petal width       0.516904    -0.117981      1.296387     0.582414

# %%
print('Correlation')
data.corr()
# Out:
# Correlation
# <ipython-input-28-a0787c4814e9>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# Data Visualization

# %%
# %matplotlib inline

# %%
data['class'].hist()
# Out:
# <Axes: >

# %%
data['petal length'].hist(bins=10)
# Out:
# <Axes: >

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data['class'].hist(bins=6)
# Out:
# <Axes: >

# %%
x=data['petal length']

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x=pd.DataFrame(x)

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['sepal length'].boxplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-0656b8ed837d> in <cell line: 1>()
# ----> 1 data['sepal length'].boxplot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'boxplot'

# %%
x=pd.DataFrame(data['sepal length'])

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x=(data['sepal length'])

# %%
x=pd.DataFrame(x)

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Scatter plot

# %%
import matplotlib.pyplot as plt

# %%
data.head(2)
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
fig, axes=plt.subplots(3,2, figsize=(15,15))
index=0
for i in range(3):
  for j in range(i+1,4):
    ax1=int(index/2)
    ax2=index % 2
    axes[ax1][ax2].scatter(data[data.columns[i]], data[data.columns[j]], color='red')
    axes[ax1][ax2].set_xlabel(data.columns[i])
    axes[ax1][ax2].set_ylabel(data.columns[j])
    index = index +1

# %%
data.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import pandas as pd

# %%
data=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)

# %%
data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.head(20)
# Out:
#       0    1    2    3            4
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa

# %%
data.tail(10)
# Out:
#        0    1    2    3               4
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
data.sample(20)
# Out:
#        0    1    2    3                4
# 87   6.3  2.3  4.4  1.3  Iris-versicolor
# 26   5.0  3.4  1.6  0.4      Iris-setosa
# 99   5.7  2.8  4.1  1.3  Iris-versicolor
# 60   5.0  2.0  3.5  1.0  Iris-versicolor
# 58   6.6  2.9  4.6  1.3  Iris-versicolor
# 75   6.6  3.0  4.4  1.4  Iris-versicolor
# 109  7.2  3.6  6.1  2.5   Iris-virginica
# 105  7.6  3.0  6.6  2.1   Iris-virginica
# 35   5.0  3.2  1.2  0.2      Iris-setosa
# 20   5.4  3.4  1.7  0.2      Iris-setosa
# 38   4.4  3.0  1.3  0.2      Iris-setosa
# 118  7.7  2.6  6.9  2.3   Iris-virginica
# 44   5.1  3.8  1.9  0.4      Iris-setosa
# 92   5.8  2.6  4.0  1.2  Iris-versicolor
# 74   6.4  2.9  4.3  1.3  Iris-versicolor
# 50   7.0  3.2  4.7  1.4  Iris-versicolor
# 17   5.1  3.5  1.4  0.3      Iris-setosa
# 46   5.1  3.8  1.6  0.2      Iris-setosa
# 107  7.3  2.9  6.3  1.8   Iris-virginica
# 123  6.3  2.7  4.9  1.8   Iris-virginica

# %%
data.columns=['sepal length','sepal width','petal length','petal width','class']

# %%
data.head(5)
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Simple statistics

# %%
from pandas.api.types import is_numeric_dtype

# %%
for col in data.columns:
  if is_numeric_dtype(data[col]):
    print('%s:'%(col))
    print('\t Mean = %.2f'%data[col].mean())
    print('\t Standard Deviation= %.2f'%data[col].std())
    print('\t Minimum = %.2f'%data[col].min())
    print('\t Maximum = %.2f'%data[col].max())
# Out:
# sepal length:
# 	 Mean = 5.84
# 	 Standard Deviation= 0.83
# 	 Minimum = 4.30
# 	 Maximum = 7.90
# sepal width:
# 	 Mean = 3.05
# 	 Standard Deviation= 0.43
# 	 Minimum = 2.00
# 	 Maximum = 4.40
# petal length:
# 	 Mean = 3.76
# 	 Standard Deviation= 1.76
# 	 Minimum = 1.00
# 	 Maximum = 6.90
# petal width:
# 	 Mean = 1.20
# 	 Standard Deviation= 0.76
# 	 Minimum = 0.10
# 	 Maximum = 2.50

# %%
data['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
data.describe(include='all')
# Out:
#         sepal length  sepal width  petal length  petal width        class
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN
